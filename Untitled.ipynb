# %%
"""Test ImageNet pretrained DenseNet"""

import cv2
import numpy as np
from keras.optimizers import SGD
import keras.backend as K

# We only test DenseNet-121 in this script for demo purpose
from densenet121 import DenseNet

im = cv2.resize(cv2.imread('resources/cat.jpg'), (224, 224)).astype(np.float32)
#im = cv2.resize(cv2.imread('shark.jpg'), (224, 224)).astype(np.float32)

# Subtract mean pixel and multiple by scaling constant
# Reference: https://github.com/shicai/DenseNet-Caffe
im[:,:,0] = (im[:,:,0] - 103.94) * 0.017
im[:,:,1] = (im[:,:,1] - 116.78) * 0.017
im[:,:,2] = (im[:,:,2] - 123.68) * 0.017

if K.image_dim_ordering() == 'th':
  # Transpose image dimensions (Theano uses the channels as the 1st dimension)
  im = im.transpose((2,0,1))

  # Use pre-trained weights for Theano backend
  weights_path = 'imagenet_models/densenet121_weights_th.h5'
else:
  print("asdasdasdasdasdasd")
  # Use pre-trained weights for Tensorflow backend
  weights_path = 'densenet121_weights_tf.h5'

# Insert a new dimension for the batch_size
im = np.expand_dims(im, axis=0)

# Test pretrained model
model = DenseNet(reduction=0.5, classes=1000, weights_path=weights_path)

sgd = SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

out = model.predict(im)

# Load ImageNet classes file
classes = []
with open('resources/classes.txt', 'r') as list_:
    for line in list_:
        classes.append(line.rstrip('\n'))

print 'Prediction: '+str(classes[np.argmax(out)])
# Out:
# Using TensorFlow backend.
# densenet121.py:45: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name="conv1")`
#   x = Convolution2D(nb_filter, 7, 7, subsample=(2, 2), name='conv1', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_1_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_1_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:174: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   concat_feat = merge([concat_feat, x], mode='concat', concat_axis=concat_axis, name='concat_'+str(stage)+'_'+str(branch))
# /usr/local/lib/python2.7/dist-packages/keras/legacy/layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_2_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_2_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_3_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_3_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_4_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_4_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_5_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_5_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_6_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv2_6_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:145: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv2_blk")`
#   x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_1_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_1_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_2_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_2_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_3_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_3_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_4_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_4_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_5_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_5_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_6_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_6_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_7_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_7_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_8_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_8_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_9_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_9_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_10_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_10_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_11_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_11_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv3_12_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv3_12_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:145: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (1, 1), use_bias=False, name="conv3_blk")`
#   x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_1_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_1_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_2_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_2_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_3_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_3_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_4_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_4_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_5_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_5_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_6_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_6_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_7_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_7_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_8_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_8_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_9_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_9_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_10_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_10_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_11_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_11_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_12_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_12_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_13_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_13_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_14_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_14_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_15_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_15_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_16_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_16_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_17_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_17_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_18_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_18_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_19_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_19_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_20_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_20_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_21_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_21_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_22_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_22_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_23_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_23_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv4_24_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv4_24_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:145: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (1, 1), use_bias=False, name="conv4_blk")`
#   x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_1_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_1_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_2_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_2_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_3_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_3_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_4_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_4_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_5_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_5_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_6_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_6_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_7_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_7_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_8_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_8_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_9_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_9_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_10_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_10_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_11_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_11_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_12_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_12_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_13_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_13_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_14_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_14_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_15_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_15_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# densenet121.py:108: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 1), use_bias=False, name="conv5_16_x1")`
#   x = Convolution2D(inter_channel, 1, 1, name=conv_name_base+'_x1', bias=False)(x)
# densenet121.py:118: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), use_bias=False, name="conv5_16_x2")`
#   x = Convolution2D(nb_filter, 3, 3, name=conv_name_base+'_x2', bias=False)(x)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-cac68cf3dda0> in <module>()
#       7
#       8 # We only test DenseNet-121 in this script for demo purpose
# ----> 9 from densenet121 import DenseNet
#      10
#      11 im = cv2.resize(cv2.imread('resources/cat.jpg'), (224, 224)).astype(np.float32)
#
# /home/rendaxuan/Documents/workspace/4032/densenet121.py in <module>()
#     180
#     181 #dense_net = DenseNet(weights_path="/home/rendaxuan/Documents/workspace/DenseNet-Keras/imagenet_models/densenet121_weights_tf.h5")
# --> 182 model = DenseNet(reduction=0.5, classes = 1000, weights_path="/home/rendaxuan/Documents/workspace/DenseNet-Keras/imagenet_models/densenet121_weights_tf.h5")
#
# /home/rendaxuan/Documents/workspace/4032/densenet121.py in DenseNet(nb_dense_block, growth_rate, nb_filter, reduction, dropout_rate, weight_decay, classes, weights_path)
#      81
#      82     if weights_path is not None:
# ---> 83       model.load_weights(weights_path)
#      84     for layer in model.layers[:-2]:
#      85         layer.trainable=False
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights(self, filepath, by_name)
#    2617             load_weights_from_hdf5_group_by_name(f, self.layers)
#    2618         else:
# -> 2619             load_weights_from_hdf5_group(f, self.layers)
#    2620
#    2621         if hasattr(f, 'close'):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights_from_hdf5_group(f, layers)
#    3066                          'containing ' + str(len(layer_names)) +
#    3067                          ' layers into a model with ' +
# -> 3068                          str(len(filtered_layers)) + ' layers.')
#    3069
#    3070     # We batch weight value assignments in a single backend call
#
# ValueError: You are trying to load a weight file containing 363 layers into a model with 366 layers.
